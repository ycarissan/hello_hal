# %%
import requests
import datetime
import pandas as pd

# %%
halid="yannickcarissan"
firstname="Yannick"
lastname="CARISSAN"

# %%
now = datetime.datetime.now()
this_year = now.year

r=requests.get("https://api.archives-ouvertes.fr/search//?q=(authIdHal_s:{}%20OR%20authFullName_sci:%22{}%20{}%22)%20AND%20docType_s:ART&rows=10000&sort=producedDate_tdate%20desc&fl=docid,docType_s,authFullName_s,authAlphaLastNameFirstNameId_fs,title_s,number_s,producedDate_s,producedDateY_i,files_s,label_s,label_xml,halId_s,doiId_s".format(halid,firstname,lastname))

response_dec = r.json()

number_of_docs = response_dec["response"]["numFound"]
docs = response_dec["response"]["docs"]
print("Number of documents : {}".format(number_of_docs))

df = pd.DataFrame()
for doc in docs:
    doctype = doc["docType_s"]
    docid = doc["docid"]
    halid = doc["halId_s"]
    title = doc["title_s"][0]
    authors_full_name=""
    for auth in doc["authFullName_s"]:
        if len(authors_full_name)>0:
            authors_full_name = authors_full_name + ", " + auth
        else:
            authors_full_name = auth

    date = doc["producedDate_s"]
    year = doc["producedDateY_i"]
    try:
        doiid = doc["doiId_s"]
    except:
        doiid = "n/a"
    try:
        file_attached = doc["files_s"][0]
    except:
        file_attached = None
    if (file_attached!=None):
        hal_ok = "\U00002714"
    else:
        hal_ok = "\U00002718"
    dict_doc = {}
    dict_doc["doctype"] = doctype
    dict_doc["docid"]   = docid
    dict_doc["halid"]   = halid
    dict_doc["title"]   = title
    dict_doc["authors"] = authors_full_name
    dict_doc["date"]    = date
    dict_doc["year"]    = year
    dict_doc["doiid"]   = doiid
    dict_doc["hal_ok"]  = hal_ok
    df = df.append(dict_doc, ignore_index=True)
# Out:
# Number of documents : 37

# %%
df
# Out:
#                                               authors        date      docid  \
# 0      Alexander Punter, Paola Nava, Yannick Carissan  2020-06-05  2980443.0
# 1   Myriam Roy, Veronika Berezhnaia, Marco Villa, ...  2020-02-17  3064338.0
# 2   Juan-Carlos Castillo, Brian Castro Agudelo, Ja...        2020  2990649.0
# 3   Marion Delorme, Alexander Punter, Raquel Olive...  2019-10-29  2354762.0
# 4   Antoine Robert, Guillaume Naulet, Harald Bock,...  2019-08-09  2332088.0
# 5      Alexander Punter, Paola Nava, Yannick Carissan  2019-02-18  2049003.0
# 6   David Pierrot, Michel Rajzmann, Yannick Cariss...  2019-02-07  2059928.0
# 7   Belgacem Bezzina, Rayenne Djémil, Djameleddine...        2018  2168191.0
# 8   Julien Racine, Yannick Carissan, Denis Hagebau...     2017-02  1789600.0
# 9   Christiane André-Barrès, Yannick Carissan, B...        2017  1587193.0
# 10  Paola Nava, Yannick Carissan, Beátrice Tuccio,...        2017  1771201.0
# 11  Nicolas Goudard, Denis Hagebaum-Reignier, Stép...  2016-09-05  1380727.0
# 12  Djameleddine Khatmi, Yannick Carissan, Denis H...     2016-06  1347226.0
# 13  Yannick Carissan, Denis Hagebaum-Reignier, Ste...     2016-04  2934622.0
# 14  Julien Racine, Denis Hagebaum-Reignier, Yannic...  2016-03-30  1560011.0
# 15  T. Butscher, Fabrice Duvernay, P. Theule, G. D...  2015-08-25  1208164.0
# 16  Olivier Schicke, Bruno Faure, Yannick Carissan...  2015-06-03  1475430.0
# 23     ART          10.1002/ejoc.201000738      ✘  hal-01447589
# 24     ART               10.1021/jp902753s      ✘  hal-01447592
# 25     ART                10.1039/b907229b      ✘  hal-01447594
# 26     ART               10.1021/jp803813e      ✘  hal-01447595
# 27     ART               10.1021/jp805559a      ✘  hal-01447596
# 28     ART      10.1016/j.ijms.2007.12.010      ✘  hal-01447597
# 29     ART               10.1021/jp075420q      ✘  hal-01447599
# 30     ART  10.1016/j.theochem.2007.04.026      ✘  hal-01447600
# 31     ART          10.1002/cphc.200600171      ✘  hal-01447602
# 32     ART          10.1002/cphc.200500673      ✘  hal-01447604
# 33     ART               10.1002/qua.20837      ✘  hal-01447606
# 34     ART               10.1021/ic034716h      ✘  hal-01447610
# 35     ART               10.1063/1.1806415      ✘  hal-00003423
# 36     ART   10.1016/S0166-1280(03)00287-2      ✘  hal-01442316
#
#                                                 title    year
# 0   Pseudopotential‐fragment spectroscopy for orga...  2020.0
# 1   Stereoselective Syntheses, Structures and Prop...  2020.0
# 2   Periselectivity in the aza-Diels–Alder Cycload...  2020.0
# 3   When cobalt-mediated [2 + 2 + 2] cycloaddition...  2019.0
# 4   Cyclobishelicenes: shape-persistent figure-eig...  2019.0
# 5   Atomic pseudopotentials for reproducing π-orbi...  2019.0
# 6   Experimental and theoretical studies of (4 + 1...  2019.0
# 7   Computational insights about the dynamic behav...  2018.0
# 8   A generalized Brillouin theorem (GBT)-like imp...  2017.0
# 9   Theoretical Studies of Autoxidation of 2‑Alkyl...  2017.0
# 10  Reply to the ‘Comment on “trans-1,2-Disiloxybe...  2017.0
# 11      HuLiS, a program to teach mesomerism and more  2016.0
# 12  Mesomerism, Ring & Substituent Effects, A Comp...  2016.0
# 13  Weight Watchers électronique : calculez votre...  2016.0
# 14  Recasting Wave Functions into Valence Bond Str...  2016.0
# 15  Formation mechanism of glycolaldehyde and ethy...  2015.0
# 16  Synthesis and Characterization of a Dinuclear ...  2015.0
# 17  Trans-1,2-disiloxybenzocyclobutene, an adequat...  2014.0
# 18  On the ring-opening of substituted cyclobutene...  2014.0
# 19  The interaction of beryllium with benzene and ...  2014.0
# 20  On the Catalysis of the Cycloisomerization of ...  2014.0
# 21       Pseudopotentials for hybridized carbon atoms  2013.0
# 22  Hydrogen abstraction from biphenyl, acenaphthy...  2010.0
# 23  InIII-Catalysed Tandem C-C and C-O Bond Format...  2010.0
# 24  Accurate Coupled Cluster Calculations of the R...  2009.0
# 25  Labile ligands on some Lewis super acids: a co...  2009.0
# 26  Hückel-Lewis Projection Method: A “Weights Wa...  2008.0
# 27  Investigation of Silicon Model Nanotubes as Po...  2008.0
# 28  Tandem mass spectrometry of doubly charged pol...  2008.0
# 29  Molecular Hydrogen Interaction with IRMOF-1: A...  2007.0
# 30  Hückel theory for Lewis structures: Hückel–Lew...  2007.0
# 31  Growing Graphene Sheets from Reactions with Me...  2006.0
# 32  Density Functional Study of Methyl Chemisorpti...  2006.0
# 33  What can we do with an effective group potential?  2006.0
# 34  Calculation of the Ground and Excited States o...  2004.0
# 35  A study of the correlation effects upon the mo...  2004.0
# 36  Effective group potentials: a powerful tool fo...  2003.0
