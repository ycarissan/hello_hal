# %%
import requests
import datetime
import pandas as pd

# %%
#name="Paola"
#name="Denis"
#name="Stéphane"
#name="Gwang-Hi"
name="Yannick"

# %%
if name=="Paola":
    halid="paola-nava"
    firstname="Paola"
    lastname="NAVA"
elif name=="Denis":
    halid="denis-hagebaum-reignier"
    firstname="Denis"
    lastname="HAGEBAUM-REIGNIER"
elif name=="Stéphane":
    halid="stephane-humbel"
    firstname="Stéphane"
    lastname="HUMBEL"
elif name=="Gwang-Hi":
    halid="gwang-hi-jeung"
    firstname="Gwang-Hi"
    lastname="JEUNG"
elif name=="Yannick":
    halid="yannickcarissan"
    firstname="Yannick"
    lastname="CARISSAN"

# %%
now = datetime.datetime.now()
this_year = now.year

r=requests.get("https://api.archives-ouvertes.fr/search//?q=(authIdHal_s:{}%20OR%20authFullName_sci:%22{}%20{}%22)%20AND%20docType_s:ART&rows=10000&sort=producedDate_tdate%20desc&fl=docid,docType_s,authFullName_s,authAlphaLastNameFirstNameId_fs,title_s,number_s,producedDate_s,producedDateY_i,files_s,label_s,label_xml,halId_s,doiId_s".format(halid,firstname,lastname))

response_dec = r.json()

number_of_docs = response_dec["response"]["numFound"]
docs = response_dec["response"]["docs"]
print("Number of documents : {}".format(number_of_docs))

df = pd.DataFrame()
for doc in docs:
    doctype = doc["docType_s"]
    docid = doc["docid"]
    halid = doc["halId_s"]
    title = doc["title_s"][0]
    authors_full_name=""
    for auth in doc["authFullName_s"]:
        if len(authors_full_name)>0:
            authors_full_name = authors_full_name + ", " + auth
        else:
            authors_full_name = auth

    date = doc["producedDate_s"]
    year = doc["producedDateY_i"]
    try:
        doiid = doc["doiId_s"]
    except:
        doiid = "n/a"
    try:
        file_attached = doc["files_s"][0]
    except:
        file_attached = None
    if (file_attached!=None):
        hal_ok = "OK" #"\U00002714"
    else:
        hal_ok = "MISSING" #\U00002718"
    dict_doc = {}
    dict_doc["doctype"] = doctype
    dict_doc["docid"]   = docid
    dict_doc["halid"]   = halid
    dict_doc["title"]   = title
    dict_doc["authors"] = authors_full_name
    dict_doc["date"]    = date
    dict_doc["year"]    = year
    dict_doc["doiid"]   = doiid
    dict_doc["hal_ok"]  = hal_ok
    df = df.append(dict_doc, ignore_index=True)
df.index=[i for i in range(1,number_of_docs+1)]
# Out:
# Number of documents : 37

# %%
df[["authors", "title", "year", "doiid", "halid", "hal_ok"]]
# Out:
#                                               authors  \
# 1      Alexander Punter, Paola Nava, Yannick Carissan
# 2   Myriam Roy, Veronika Berezhnaia, Marco Villa, ...
# 3   Juan-Carlos Castillo, Brian Castro Agudelo, Ja...
# 4   Marion Delorme, Alexander Punter, Raquel Olive...
# 5   Antoine Robert, Guillaume Naulet, Harald Bock,...
# 6      Alexander Punter, Paola Nava, Yannick Carissan
# 7   David Pierrot, Michel Rajzmann, Yannick Cariss...
# 8   Belgacem Bezzina, Rayenne Djémil, Djameleddine...
# 9   Julien Racine, Yannick Carissan, Denis Hagebau...
# 10  Christiane André-Barrès, Yannick Carissan, B...
# 11  Paola Nava, Yannick Carissan, Beátrice Tuccio,...
# 12  Nicolas Goudard, Denis Hagebaum-Reignier, Stép...
# 13  Djameleddine Khatmi, Yannick Carissan, Denis H...
# 14  Yannick Carissan, Denis Hagebaum-Reignier, Ste...
# 15  Julien Racine, Denis Hagebaum-Reignier, Yannic...
# 16  T. Butscher, Fabrice Duvernay, P. Theule, G. D...
# 17  Olivier Schicke, Bruno Faure, Yannick Carissan...
# 18  Jean Drujon, Raphaël Rahmani, Virginie Héran, ...
# 19                       Paola Nava, Yannick Carissan
# 20  Nicolas Fernandez, Yves Ferro, Yannick Carissa...
# 21  Paola Nava, Yannick Carissan, Jean Drujon, Fan...
# 22                      Jean Drujon, Yannick Carissan
# 23                      Yannick Carissan, Wim Klopper
# 24  Vito Vece, Jérémy Ricci, Sophie Poulain-Martin...
# 25  Wim Klopper, Rafał A. Bachorz, David P. Tew, J...
# 26      Paola Nava, Yannick Carissan, Stéphane Humbel
# 27  Yannick Carissan, Denis Hagebaum-Reignier, Nic...
# 28  George P. Lithoxoos, Jannis Samios, Yannick Ca...
# 29  Marion Girod, Yannick Carissan, Stéphane Humbe...
# 30  E. Klontzas, A. Mavrandonakis, W. Klopper, Yan...
# 31  Denis Hagebaum-Reignier, Raphaël Girardi, Yann...
# 32                      Yannick Carissan, Wim Klopper
# 33  Barbara V. Unterreiner, Yannick Carissan, Wim ...
# 34  Yannick Carissan, Fabienne Bessac, Fabienne Al...
# 35  Yannick Carissan, Jean-Louis Heully, Fabienne ...
# 36  Jean-Louis Heully, Yannick Carissan, Nathalie ...
# 37  Fabienne Bessac, Fabienne Alary, Yannick Caris...
#
#                                                 title    year  \
# 1   Pseudopotential‐fragment spectroscopy for orga...  2020.0
# 2   Stereoselective Syntheses, Structures and Prop...  2020.0
# 3   Periselectivity in the aza-Diels–Alder Cycload...  2020.0
# 4   When cobalt-mediated [2 + 2 + 2] cycloaddition...  2019.0
# 5   Cyclobishelicenes: shape-persistent figure-eig...  2019.0
# 6   Atomic pseudopotentials for reproducing π-orbi...  2019.0
# 7   Experimental and theoretical studies of (4 + 1...  2019.0
# 8   Computational insights about the dynamic behav...  2018.0
# 9   A generalized Brillouin theorem (GBT)-like imp...  2017.0
# 10  Theoretical Studies of Autoxidation of 2‑Alkyl...  2017.0
# 11  Reply to the ‘Comment on “trans-1,2-Disiloxybe...  2017.0
# 12      HuLiS, a program to teach mesomerism and more  2016.0
# 13  Mesomerism, Ring & Substituent Effects, A Comp...  2016.0
# 14  Weight Watchers électronique : calculez votre...  2016.0
# 15  Recasting Wave Functions into Valence Bond Str...  2016.0
# 16  Formation mechanism of glycolaldehyde and ethy...  2015.0
# 17  Synthesis and Characterization of a Dinuclear ...  2015.0
# 18  Trans-1,2-disiloxybenzocyclobutene, an adequat...  2014.0
# 19  On the ring-opening of substituted cyclobutene...  2014.0
# 20  The interaction of beryllium with benzene and ...  2014.0
# 21  On the Catalysis of the Cycloisomerization of ...  2014.0
# 22       Pseudopotentials for hybridized carbon atoms  2013.0
# 23  Hydrogen abstraction from biphenyl, acenaphthy...  2010.0
# 24  InIII-Catalysed Tandem C-C and C-O Bond Format...  2010.0
# 25  Accurate Coupled Cluster Calculations of the R...  2009.0
# 26  Labile ligands on some Lewis super acids: a co...  2009.0
# 27  Hückel-Lewis Projection Method: A “Weights Wa...  2008.0
# 28  Investigation of Silicon Model Nanotubes as Po...  2008.0
# 29  Tandem mass spectrometry of doubly charged pol...  2008.0
# 30  Molecular Hydrogen Interaction with IRMOF-1: A...  2007.0
# 31  Hückel theory for Lewis structures: Hückel–Lew...  2007.0
# 32  Growing Graphene Sheets from Reactions with Me...  2006.0
# 33  Density Functional Study of Methyl Chemisorpti...  2006.0
# 34  What can we do with an effective group potential?  2006.0
# 35  Calculation of the Ground and Excited States o...  2004.0
# 36  A study of the correlation effects upon the mo...  2004.0
# 37  Effective group potentials: a powerful tool fo...  2003.0
#
#                              doiid         halid   hal_ok
# 1                10.1002/qua.26180  hal-02980288       OK
# 2           10.1002/anie.201913200  hal-03064338       OK
# 3          10.1021/acs.joc.0c00767  hal-02990649       OK
# 4               10.1039/C9DT03311D  hal-02354762       OK
# 5           10.1002/chem.201902637  hal-02265747       OK
# 6                10.1002/qua.25914  hal-02048996       OK
# 7                 10.1002/poc.3939  hal-02059903       OK
# 8        10.1007/s10847-018-0822-0  hal-02168191       OK
# 9     10.1016/j.comptc.2017.01.019  hal-01469404       OK
# 10        10.1021/acsomega.7b00989  hal-01587193       OK
# 11              10.1039/c6cp07923g  hal-01651059       OK
# 12  10.1088/1742-6596/738/1/012015  hal-01380727       OK
# 13      10.5923/j.jlce.20160402.01  hal-01347226       OK
# 14                             n/a  hal-01347244       OK
# 15               10.1002/jcc.24267  hal-01306875       OK
# 16           10.1093/mnras/stv1706  hal-01208164       OK
# 17          10.1002/ejic.201500280  hal-01475430  MISSING
# 18              10.1039/c3cp55077j  hal-01066302       OK
# 19              10.1039/c4cp01695e  hal-01141483       OK
# 20              10.1039/c3cp54062f  hal-01447585  MISSING
# 21          10.1002/cctc.201300952  hal-01347469  MISSING
# 22               10.1002/jcc.23104  hal-01447588  MISSING
# 23  10.1016/j.theochem.2009.10.017  hal-01447590  MISSING
# 24          10.1002/ejoc.201000738  hal-01447589  MISSING
# 25               10.1021/jp902753s  hal-01447592  MISSING
# 26                10.1039/b907229b  hal-01447594  MISSING
# 27               10.1021/jp803813e  hal-01447595  MISSING
# 28               10.1021/jp805559a  hal-01447596  MISSING
# 29      10.1016/j.ijms.2007.12.010  hal-01447597  MISSING
# 30               10.1021/jp075420q  hal-01447599  MISSING
# 31  10.1016/j.theochem.2007.04.026  hal-01447600  MISSING
# 32          10.1002/cphc.200600171  hal-01447602  MISSING
# 33          10.1002/cphc.200500673  hal-01447604  MISSING
# 34               10.1002/qua.20837  hal-01447606  MISSING
# 35               10.1021/ic034716h  hal-01447610  MISSING
# 36               10.1063/1.1806415  hal-00003423  MISSING
# 37   10.1016/S0166-1280(03)00287-2  hal-01442316  MISSING

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    
    if val == "\U00002714":
        color = "green"
    elif val == "\U00002718":
        color = "red"
    else:
        color="black"
    return 'color: %s' % color

# %%
s = df.style.applymap(color_negative_red, subset=['hal_ok'])
